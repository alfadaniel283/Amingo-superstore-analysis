# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#
# File ~/Documents/retail-sales-analysis/.venv/lib64/python3.14/site-packages/pandas/__init__.py:11
#       9 for _dependency in _hard_dependencies:
#      10     try:
# ---> 11         __import__(_dependency)
#      12     except ImportError as _e:  # pragma: no cover
#      13         raise ImportError(
#      14             f"Unable to import required dependency {_dependency}. "
#      15             "Please see the traceback for details."
#      16         ) from _e
#
# File ~/Documents/retail-sales-analysis/.venv/lib64/python3.14/site-packages/numpy/__init__.py:112
#     109 from . import _distributor_init
#     111 try:
# --> 112     from numpy.__config__ import show_config
#     113 except ImportError as e:
# ...

# %%
df = pd.read_csv('/home/luman/Documents/retail-sales-analysis/SuperStoreOrders.csv')

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='str')
